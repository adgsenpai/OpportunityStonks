# %% [markdown]
# # Investigating Yahoo Financial API

# %% [markdown]
# ### Installation of modules

# %% [markdown]
# think we need the Yahoo API, Pandas, Numpy and maybe Matlab lets install it.

# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
# Using legacy 'setup.py install' for yahoofinancials, since package 'wheel' is not installed.
# Using legacy 'setup.py install' for multitasking, since package 'wheel' is not installed.
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.25.1
#     Uninstalling requests-2.25.1:
#       Successfully uninstalled requests-2.25.1
#     Running setup.py install for multitasking: started
#     Running setup.py install for multitasking: finished with status 'done'
#     Running setup.py install for yahoofinancials: started
#     Running setup.py install for yahoofinancials: finished with status 'done'
# ...

# %% [markdown]
# ### Importing Modules

# %%
import pandas as pd
import yfinance as yf
from yahoofinancials import YahooFinancials
import pandas as pd
import numpy as np

# %% [markdown]
# ### Playing with the API - Lets get info for Apple Stonks

# %%
aapl_df = yf.download('AAPL', 
                      start='2019-01-01', 
                      end='2021-06-12', 
                      progress=False,
)
aapl_df.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2018-12-31  39.632500  39.840000  39.119999  39.435001  38.282604  140014000
# 2019-01-02  38.722500  39.712502  38.557499  39.480000  38.326290  148158800
# 2019-01-03  35.994999  36.430000  35.500000  35.547501  34.508705  365248800
# 2019-01-04  36.132500  37.137501  35.950001  37.064999  35.981873  234428400
# 2019-01-07  37.174999  37.207500  36.474998  36.982498  35.901768  219111200

# %% [markdown]
# ### This downloads all historical data for any stonk with a stonk code

# %%
aapl_df = yf.download('AAPL')
aapl_df
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1980-12-12    0.128348    0.128906    0.128348    0.128348    0.100453
# 1980-12-15    0.122210    0.122210    0.121652    0.121652    0.095213
# 1980-12-16    0.113281    0.113281    0.112723    0.112723    0.088224
# 1980-12-17    0.115513    0.116071    0.115513    0.115513    0.090408
# 1980-12-18    0.118862    0.119420    0.118862    0.118862    0.093029
# ...                ...         ...         ...         ...         ...
# 2022-01-24  160.020004  162.300003  154.699997  161.619995  161.619995
# 2022-01-25  158.979996  162.759995  157.020004  159.779999  159.779999
# 2022-01-26  163.500000  164.389999  157.820007  159.690002  159.690002
# 2022-01-27  162.449997  163.839996  158.279999  159.220001  159.220001
# 2022-01-28  165.710007  170.350006  162.800003  170.330002  170.330002
#
#                Volume
# Date
# ...

# %% [markdown]
# quite alot of data to play with this API is powerful!

# %% [markdown]
# ### Sketching Apple Stonk

# %%
ticker = yf.Ticker('AAPL')
aapl_df = ticker.history(period="max")
aapl_df['Close'].plot(title="APPLE's stock price")
# Out:
# <AxesSubplot:title={'center':"APPLE's stock price"}, xlabel='Date'>

# %% [markdown]
# #### Recommendations for Stonk by Analysts

# %%
ticker.recommendations
# Out:
#                                     Firm    To Grade From Grade Action
# Date
# 2012-02-09 08:17:00    Canaccord Genuity         Buy              main
# 2012-03-08 07:33:00       FBN Securities  Outperform              main
# 2012-03-13 06:08:00            Jefferies         Buy              main
# 2012-03-14 06:13:00       Morgan Stanley  Overweight              main
# 2012-03-14 08:21:00    Canaccord Genuity         Buy              main
# ...                                  ...         ...        ...    ...
# 2022-01-28 12:18:25        Raymond James  Outperform              main
# 2022-01-28 12:45:37       Morgan Stanley  Overweight              main
# 2022-01-28 13:01:39        Deutsche Bank         Buy              main
# 2022-01-28 14:19:01  New Street Research     Neutral       Sell     up
# 2022-01-28 15:10:56          Oppenheimer  Outperform              main
#
# [828 rows x 4 columns]

# %% [markdown]
# #### Stonk holders of Apple Shares

# %%
ticker.institutional_holders
# Out:
#                                 Holder      Shares Date Reported   % Out  \
# 0           Vanguard Group, Inc. (The)  1266332667    2021-09-29  0.0775
# 1                       Blackrock Inc.  1026223983    2021-09-29  0.0628
# 2              Berkshire Hathaway, Inc   887135554    2021-09-29  0.0543
# 3             State Street Corporation   622163541    2021-09-29  0.0381
# 4                             FMR, LLC   350617759    2021-09-29  0.0215
# 5        Geode Capital Management, LLC   259894947    2021-09-29  0.0159
# 6           Northern Trust Corporation   195321532    2021-09-29  0.0120
# 7        Price (T.Rowe) Associates Inc   188489966    2021-09-29  0.0115
# 8    Norges Bank Investment Management   167580974    2020-12-30  0.0103
# 9  Bank Of New York Mellon Corporation   149381117    2021-09-29  0.0091
#
#           Value
# 0  179186072380
# 1  145210693594
# 2  125529680891
# 3   88036141051
# 4   49612412898
# 5   36775135000
# 6   27637996778
# 7   26671330189
# ...

# %% [markdown]
# i think our work is done, understand the API fully now its time to work!
