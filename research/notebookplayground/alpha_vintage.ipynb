# %%
# !pip install alpha_vantage

# %%
from alpha_vantage.timeseries import TimeSeries
ts = TimeSeries(key='9DX8CG6IA9EIFY26', output_format='pandas')
data, meta_data = ts.get_intraday(symbol='AAPL',interval='1min', outputsize='full')

# %%
data
# Out:
#                      1. open  2. high  3. low  4. close  5. volume
# date
# 2022-01-28 20:00:00   170.73   170.73  170.55  170.7000     4734.0
# 2022-01-28 19:59:00   170.79   170.80  170.72  170.7500     9686.0
# 2022-01-28 19:58:00   170.72   170.79  170.72  170.7700     4351.0
# 2022-01-28 19:57:00   170.71   170.77  170.71  170.7699     6420.0
# 2022-01-28 19:56:00   170.73   170.73  170.70  170.7000     1081.0
# ...                      ...      ...     ...       ...        ...
# 2022-01-18 04:05:00   170.55   170.68  170.50  170.5000     4344.0
# 2022-01-18 04:04:00   170.55   170.55  170.55  170.5500      513.0
# 2022-01-18 04:03:00   170.80   170.80  170.56  170.5900     1851.0
# 2022-01-18 04:02:00   170.61   170.66  170.61  170.6100     1384.0
# 2022-01-18 04:01:00   170.85   170.89  170.52  170.5200     8022.0
#
# [8052 rows x 5 columns]
